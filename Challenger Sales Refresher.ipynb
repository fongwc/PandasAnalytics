# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c_sales = pd.read_csv('ChallengerSales.csv')

# %%
c_sales.head()
# Out:
#     Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0  6-Mar  Mon    Morning  Female        High             4     136.97
# 1  6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2  6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3  6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4  6-Mar  Mon  Afternoon    Male      Medium             4     147.32
#
#    HighItem Member Region
# 0     79.97    Yes   West
# 1     25.55     No   West
# 2     90.47    Yes   West
# 3      6.82     No   East
# 4     83.21    Yes   West

# %%
c_sales.tail()
# Out:
#        Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 395  25-Jun  Sat  Afternoon    Male      Medium             6     268.39
# 396  25-Jun  Sat  Afternoon  Female      Medium             3     169.11
# 397  25-Jun  Sat  Afternoon    Male      Medium             6     242.46
# 398  25-Jun  Sat  Afternoon    Male      Medium             4     168.64
# 399  25-Jun  Sat  Afternoon  Female         Low             1     107.59
#
#      HighItem Member Region
# 395    170.13     No   East
# 396     80.08     No   East
# 397    180.66     No   West
# 398     85.79     No   East
# 399    107.59     No   East

# %%
c_sales.shape
# Out:
# (400, 10)

# %%
c_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          400 non-null    object
#  1   Day           400 non-null    object
#  2   Time          400 non-null    object
#  3   Gender        400 non-null    object
#  4   BuyCategory   400 non-null    object
#  5   ItemsOrdered  400 non-null    int64
#  6   TotalCost     400 non-null    float64
#  7   HighItem      400 non-null    float64
#  8   Member        400 non-null    object
#  9   Region        400 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 31.4+ KB

# %%
# for numberical data

c_sales.describe()
# Out:
#        ItemsOrdered   TotalCost    HighItem
# count    400.000000  400.000000  400.000000
# mean       3.467500  153.818025  100.442625
# std        2.022169   97.373038   67.051120
# min        1.000000    6.820000    6.820000
# 25%        2.000000   83.322500   56.222500
# 50%        3.000000  126.720000   83.395000
# 75%        4.000000  205.245000  119.440000
# max       11.000000  485.010000  381.330000

# %%
# for categorical data

c_sales.describe(include = "O")
# Out:
#           Date  Day  Gender BuyCategory Member Region
# count      400  400     400         400    400    400
# unique     112    7       2           3      2      4
# top     25-Mar  Sat  Female         Low     No   West
# freq        10  101     234         160    306    121

# %%
c_sales.values
# Out:
# array([['6-Mar', 'Mon', 'Female', ..., 'Yes', 'West', 34.24],
#        ['6-Mar', 'Mon', 'Female', ..., 'No', 'West', 25.55],
#        ['6-Mar', 'Mon', 'Female', ..., 'Yes', 'West', 22.79],
#        ...,
#        ['25-Jun', 'Sat', 'Male', ..., 'No', 'West', 40.41],
#        ['25-Jun', 'Sat', 'Male', ..., 'No', 'East', 42.16],
#        ['25-Jun', 'Sat', 'Female', ..., 'No', 'East', 107.59]],
#       dtype=object)

# %%
c_sales.columns
# Out:
# Index(['Date', 'Day', 'Gender', 'BuyCategory', 'ItemsOrdered', 'TotalCost',
#        'HighItem', 'Member', 'Region', 'AvgCost'],
#       dtype='object')

# %%
c_sales.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
# checking what's the value under 'Region' in row 5

c_sales.loc[4, 'Region']
# Out:
# 'West'

# %%
# showing the column information for all rows

c_sales.loc[ : , 'Region']
# Out:
# 0      West
# 1      West
# 2      West
# 3      East
# 4      West
#        ...
# 395    East
# 396    East
# 397    West
# 398    East
# 399    East
# Name: Region, Length: 400, dtype: object

# %%
# showing all information in row 5

c_sales.loc[4]
# Out:
# Date                6-Mar
# Day                   Mon
# Time            Afternoon
# Gender               Male
# BuyCategory        Medium
# ItemsOrdered            4
# TotalCost          147.32
# HighItem            83.21
# Member                Yes
# Region               West
# Name: 4, dtype: object

# %%
# changing to a DF

df1 = pd.DataFrame(c_sales.loc[4])
df1
# Out:
#                       4
# Date              6-Mar
# Day                 Mon
# Time          Afternoon
# Gender             Male
# BuyCategory      Medium
# ItemsOrdered          4
# TotalCost        147.32
# HighItem          83.21
# Member              Yes
# Region             West

# %%
df1.rename(columns = {"4" : "Info"})
df1
# Out:
#                       4
# Date              6-Mar
# Day                 Mon
# Time          Afternoon
# Gender             Male
# BuyCategory      Medium
# ItemsOrdered          4
# TotalCost        147.32
# HighItem          83.21
# Member              Yes
# Region             West

# %%
# specifying which rows and columns to fetch information

c_sales.loc[[0,5,8,88],['Gender', 'Member','TotalCost']]
# Out:
#     Gender Member  TotalCost
# 0   Female    Yes     136.97
# 5   Female     No     142.15
# 8     Male     No      25.83
# 88  Female     No      82.34

# %%
c_sales
# Out:
#        Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0     6-Mar  Mon    Morning  Female        High             4     136.97
# 1     6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2     6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3     6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4     6-Mar  Mon  Afternoon    Male      Medium             4     147.32
# ..      ...  ...        ...     ...         ...           ...        ...
# 395  25-Jun  Sat  Afternoon    Male      Medium             6     268.39
# 396  25-Jun  Sat  Afternoon  Female      Medium             3     169.11
# 397  25-Jun  Sat  Afternoon    Male      Medium             6     242.46
# 398  25-Jun  Sat  Afternoon    Male      Medium             4     168.64
# 399  25-Jun  Sat  Afternoon  Female         Low             1     107.59
#
#      HighItem Member Region
# 0       79.97    Yes   West
# 1       25.55     No   West
# ...

# %%
# create a new calculated column

c_sales['AvgCost'] = round(c_sales['TotalCost'] / c_sales['ItemsOrdered'],2)

# %%
c_sales.head()
# Out:
#     Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0  6-Mar  Mon    Morning  Female        High             4     136.97
# 1  6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2  6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3  6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4  6-Mar  Mon  Afternoon    Male      Medium             4     147.32
#
#    HighItem Member Region  AvgCost
# 0     79.97    Yes   West    34.24
# 1     25.55     No   West    25.55
# 2     90.47    Yes   West    22.79
# 3      6.82     No   East     6.82
# 4     83.21    Yes   West    36.83

# %%
# finding value of cell in row 3 and column 9
c_sales.iloc[2,9]
# Out:
# 'West'

# %%
# finding data by using iloc

c_sales.iloc[2, :]
# Out:
# Date                6-Mar
# Day                   Mon
# Time            Afternoon
# Gender             Female
# BuyCategory        Medium
# ItemsOrdered            5
# TotalCost          113.95
# HighItem            90.47
# Member                Yes
# Region               West
# AvgCost             22.79
# Name: 2, dtype: object

# %%
type(c_sales.iloc[2, :])
# Out:
# pandas.core.series.Series

# %%
# renaming a column, inplace must be true to be reflected in DF

c_sales.rename(columns = {'Time': 'Timing'}, inplace = True)
c_sales
# Out:
#        Date  Day     Timing  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0     6-Mar  Mon    Morning  Female        High             4     136.97
# 1     6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2     6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3     6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4     6-Mar  Mon  Afternoon    Male      Medium             4     147.32
# ..      ...  ...        ...     ...         ...           ...        ...
# 395  25-Jun  Sat  Afternoon    Male      Medium             6     268.39
# 396  25-Jun  Sat  Afternoon  Female      Medium             3     169.11
# 397  25-Jun  Sat  Afternoon    Male      Medium             6     242.46
# 398  25-Jun  Sat  Afternoon    Male      Medium             4     168.64
# 399  25-Jun  Sat  Afternoon  Female         Low             1     107.59
#
#      HighItem Member Region  AvgCost
# 0       79.97    Yes   West    34.24
# ...

# %%
# dropping a column - inplace must be true for change to be reflected in DF

c_sales.drop(columns = ['Timing'], inplace = True)
c_sales.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-784727531380> in <module>
#       1 # dropping a column - inplace must be true for change to be reflected in DF
#       2
# ----> 3 c_sales.drop(columns = ['Timing'], inplace = True)
#       4 c_sales.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
# as Timing column has been deleted, which is why the error message above

c_sales.head()
# Out:
#     Date  Day  Gender BuyCategory  ItemsOrdered  TotalCost  HighItem Member  \
# 0  6-Mar  Mon  Female        High             4     136.97     79.97    Yes
# 1  6-Mar  Mon  Female      Medium             1      25.55     25.55     No
# 2  6-Mar  Mon  Female      Medium             5     113.95     90.47    Yes
# 3  6-Mar  Mon  Female         Low             1       6.82      6.82     No
# 4  6-Mar  Mon    Male      Medium             4     147.32     83.21    Yes
#
#   Region  AvgCost
# 0   West    34.24
# 1   West    25.55
# 2   West    22.79
# 3   East     6.82
# 4   West    36.83

# %%
fil_member_gender = (c_sales['Member'] == 'Yes') & (c_sales['Gender'] == 'Female')
fil_member_gender
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Length: 400, dtype: bool

# %%
fil_member_gender1 = c_sales[(c_sales['Member'] == 'Yes') & (c_sales['Gender'] == 'Female')]
fil_member_gender1.head(15)
# Out:
#        Date    Day  Gender BuyCategory  ItemsOrdered  TotalCost  HighItem  \
# 0     6-Mar    Mon  Female        High             4     136.97     79.97
# 2     6-Mar    Mon  Female      Medium             5     113.95     90.47
# 10    8-Mar    Wed  Female      Medium             2      54.52     54.38
# 16   10-Mar    Fri  Female      Medium             6      96.53     93.68
# 17   10-Mar    Fri  Female      Medium             4      77.44     77.28
# 22   12-Mar    Sun  Female        High             9     429.98    381.33
# 25   14-Mar   Tues  Female      Medium             5     139.51    133.11
# 29   15-Mar    Wed  Female        High             2      83.38     71.02
# 55   23-Mar  Thurs  Female        High             8     377.18    320.31
# 70   26-Mar    Mon  Female         Low             2      65.51     37.24
# 77   28-Mar  Thurs  Female        High             9     403.60    160.86
# 81   29-Mar    Fri  Female         Low             2      32.65     21.13
# ...

# %%
fil_member_gender1.shape
# Out:
# (61, 10)

# %%
fil_member_gender2 = c_sales[(c_sales['Member'] == 'Yes') | (c_sales['Gender'] == 'Female')]
fil_member_gender2.head()
# Out:
#     Date  Day  Gender BuyCategory  ItemsOrdered  TotalCost  HighItem Member  \
# 0  6-Mar  Mon  Female        High             4     136.97     79.97    Yes
# 1  6-Mar  Mon  Female      Medium             1      25.55     25.55     No
# 2  6-Mar  Mon  Female      Medium             5     113.95     90.47    Yes
# 3  6-Mar  Mon  Female         Low             1       6.82      6.82     No
# 4  6-Mar  Mon    Male      Medium             4     147.32     83.21    Yes
#
#   Region  AvgCost
# 0   West    34.24
# 1   West    25.55
# 2   West    22.79
# 3   East     6.82
# 4   West    36.83

# %%
fil_member_gender2.shape
# Out:
# (267, 10)

# %%
c_sales.shape
# Out:
# (400, 10)

# %%
len(c_sales)
# Out:
# 400

# %%
c_sales['ItemsOrdered'].sum()
# Out:
# 1387

# %%
c_sales.ItemsOrdered.sum()
# Out:
# 1387

# %%
c_sales.ItemsOrdered.count()
# Out:
# 400

# %%
c_sales.TotalCost.mean()
# Out:
# 153.8180250000001

# %%
c_sales.TotalCost.max()
# Out:
# 485.01

# %%
c_sales.TotalCost.min()
# Out:
# 6.82

# %%
c_sales.TotalCost.median()
# Out:
# 126.72

# %%
c_sales.Region.value_counts()
# Out:
# West       121
# East       115
# South       93
# Central     71
# Name: Region, dtype: int64

# %%
c_sales.Region.value_counts(normalize = True)
# Out:
# West       0.3025
# East       0.2875
# South      0.2325
# Central    0.1775
# Name: Region, dtype: float64

# %%
c_sales.Gender.value_counts(normalize = True)
# Out:
# Female    0.585
# Male      0.415
# Name: Gender, dtype: float64

# %%
c_sales.sort_values(by = 'ItemsOrdered', ascending = False)
# Out:
#        Date   Day  Gender BuyCategory  ItemsOrdered  TotalCost  HighItem  \
# 312   4-Jun   Sat    Male        High            11     485.01     87.44
# 343  11-Jun   Sat    Male        High            10     451.03     78.06
# 210   5-May  Tues    Male        High            10     463.40    226.18
# 130  11-Apr   Sat  Female        High             9     370.26    337.44
# 293  28-May   Sat    Male      Medium             9     256.70     67.72
# ..      ...   ...     ...         ...           ...        ...       ...
# 197   2-May   Sat    Male         Low             1      34.31     34.31
# 194   2-May   Sat    Male      Medium             1      87.10     87.10
# 177  25-Apr   Sat    Male      Medium             1      72.80     72.80
# 170  24-Apr   Fri  Female         Low             1      42.07     42.07
# 399  25-Jun   Sat  Female         Low             1     107.59    107.59
#
#     Member   Region  AvgCost
# 312    Yes     East    44.09
# 343    Yes     East    45.10
# ...

# %%
plt.plot([0,1,1,0,0], [0,0,1,1,0]) # plotting a square
